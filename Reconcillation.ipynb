# %%
table_names = ["django_migrations",
"django_content_type",
"auth_permission",
"auth_group",
"auth_group_permissions",
"app_users",
"fund_request",
"articles",
"public_beneficiary_entries",
"order_entries",
"institutions_beneficiary_entries",
"fund_request_recipients",
"fund_request_documents",
"district_beneficiary_entries",
"district_master",
"audit_logs",
"app_users_groups",
"app_users_user_permissions",
"django_admin_log",
"user_module_permissions",
"dashboard_settings",
"vendors",
"fund_request_articles",
"purchase_order",
"purchase_order_items",
"seat_allocation_rows",
"event_sessions",
"label_generation_rows",
"sequence_list_items",
"token_generation_rows",
"application_attachments",
"django_session",
"public_beneficiary_history"]

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# Example:
# engine = create_engine("postgresql+psycopg2://user:pass@host:5432/dbname")


query = text(f"SELECT * FROM {table_names[13]};")

with engine.connect() as conn:
    result = conn.execute(query)
    df = pd.DataFrame(result.fetchall(), columns=result.keys())

df.head()
# Out:
#      id                       created_at                       updated_at  \
# 0  1145 2026-04-24 12:25:48.776028+00:00 2026-04-24 12:25:48.776585+00:00
# 1  1146 2026-04-24 12:25:48.934963+00:00 2026-04-24 12:25:48.935340+00:00
# 2  1147 2026-04-24 12:25:49.098398+00:00 2026-04-24 12:25:49.098633+00:00
# 3  1148 2026-04-24 12:25:49.252338+00:00 2026-04-24 12:25:49.252549+00:00
# 4  1149 2026-04-24 12:25:49.414388+00:00 2026-04-24 12:25:49.414599+00:00
#
#   application_number article_cost_per_unit  quantity total_amount  \
# 0               D022              25000.00         1     25000.00
# 1               D022              20000.00         1     20000.00
# 2               D022              20000.00         1     20000.00
# 3               D022              20000.00         1     20000.00
# 4               D022              20000.00         1     20000.00
#
#             notes     status  article_id created_by_id  district_id  \
# ...
